# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import pickle as pkl
from datetime import datetime, timedelta, time
from glob import glob
import sahara_work as sw
import dask.dataframe as dd

colors = {1: "#29B397", 2:'#04729C', 3:"#F7BC30"}
# Out:
# /hlabhome/wg-mjames/.conda/envs/james_test/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /hlabhome/wg-mjames/.conda/envs/james_test/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ## 1. Loading Prediction Data

# %%
# Run this cell to load from directory

DIR = '/media/HlabShare/Sleep_Scoring_ckbn_noscoring_m77s2p/*'
#DIR = '/media/HlabShare/Sleep_Scoring_ckbn_noscoring_m101s1/*'
FILE_LENGTH = 900

def recursive_search(search_term: str, curr_dir = DIR) -> list:
    filez = glob(curr_dir)
    filez_found = [file for file in filez if search_term in file]
    if len(filez_found) == 0: 
        return_file = []
        for subfolder in filez:
            return_file += recursive_search(search_term, subfolder+'/*')
        return return_file
    else: 
        return filez_found
    
all_prediction_filez = recursive_search('FinalStateshr')

# %%
# Run this cell to load from numpy

all_prediction_filez = np.load("/media/HlabShare/james_work/paths_to_FinalStates_v3_add5min.npy")

# %%
# Exclude problematic files
all_prediction_filez = [file for file in all_prediction_filez if 'caf2607092020' not in file and 'caf89_04152021' not in file and 'caf89_04162021' not in file]

# %%
# Check duplicates

if len(set(all_prediction_filez)) - len(all_prediction_filez) == 0:
    pass
else:
    all_prediction_filez = list(set(all_prediction_filez))

# %% [markdown]
# ## Functions to compute statistics

# %%
from typing import Any

def dtify(datetimestring):
    """
    Usage:
    dtify('2020-12-28_11-16-26') --> returns datetime.datetime(2020, 12, 28, 11, 16, 26)
    """
    import datetime

    try:
        dtobj = datetime.datetime.strptime(datetimestring, "%Y%m%dT%H%M%S")
    except:
        dtobj = datetime.datetime.strptime(datetimestring, "%Y-%m-%d_%H-%M-%S")
    return dtobj

def extract_animal_name(path:str) -> Any:
    return re.search('\w{3}\d{5}', path).group()

def extract_restart_date(path:str) -> datetime:
    return dtify(re.search(r'\d{4}-\d{2}-\d{2}_\d{2}-\d{2}-\d{2}', path).group())


def make_dataframe(file_path:str) -> pd.DataFrame:
    preserve_digit = lambda matchobj, str: str + matchobj.groups()[0]
    wrapper_probs = lambda matchobj: preserve_digit(matchobj, 'FinalStates_probhr')
    wrapper_thetas = lambda matchobj: preserve_digit(matchobj, 'thet')
    wrapper_deltas = lambda matchobj: preserve_digit(matchobj, 'delt')
    
    path_stem = file_path[:-19]

    predictions = np.load(file_path)
    probs = np.load(re.sub(r'FinalStateshr(\d{1,2})', wrapper_probs, file_path)).max(axis=1)
    thetas = np.load(re.sub(r'FinalStateshr(\d{1,2})', wrapper_thetas, file_path))
    deltas = np.load(re.sub(r'FinalStateshr(\d{1,2})', wrapper_deltas, file_path))
    animal_name = extract_animal_name(file_path)
    birthday = sw.get_birthday(animal_name.upper())
    
    start_time = extract_restart_date(file_path)
    times = [start_time+timedelta(seconds=ind*4) for ind in range(len(predictions))]

    return pd.DataFrame({
        "State" : predictions,
        "Prob" : probs,
        "Delta" : (deltas[np.array(range(FILE_LENGTH * 2)) % 2 == 0] + deltas[np.array(range(FILE_LENGTH * 2)) % 2 == 1])/2,
        "Theta": (thetas[np.array(range(FILE_LENGTH * 2)) % 2 == 0] + thetas[np.array(range(FILE_LENGTH * 2)) % 2 == 1])/2,
        "Birthday" : birthday,
        'Time': times,
        'Animal' : [animal_name] * FILE_LENGTH
    })

def get_isLight(pred_df: pd.DataFrame) -> pd.Series:
    mask1 = pred_df.Time.dt.time >= time(hour=7, minute=30)
    mask2 = pred_df.Time.dt.time < time(hour=19, minute=30)
    return mask1 & mask2

def compute_state_percentages(pred_df: pd.DataFrame) -> pd.DataFrame:
    pred_df['isLight'] = get_isLight(pred_df)
    stats = (pred_df.groupby(['isLight', 'State']).count()[['Time']] / FILE_LENGTH).reset_index()
    stats['Animal'] = pred_df.Animal[0]
    stats['Date'] = pred_df.Time[0]
    return stats.set_index(['Animal', 'Date'])

# %%
# Compile all files

animal = list(map(extract_animal_name, all_prediction_filez))
date = list(map(extract_restart_date, all_prediction_filez))

data = pd.DataFrame(
    {
        'Animal' : animal,
        "Date": date,
        'file': all_prediction_filez
    }
)

data = data.set_index(['Animal', 'Date']).sort_index()

# %% [markdown]
# ## Create Raw Data Frames

# %%
# Run this cell to aggregate all raw predictions

# for ind, file in enumerate(all_prediction_filez):
#     make_dataframe(file).to_parquet(f'./data/Raw_dataframe/partition_{ind}.parquet', compression='gzip')

# %%
# Load predictions

#all_data = dd.read_parquet('./data/Raw_dataframe/', parquet_file_extension='.parquet')

# %% [markdown]
# ## Compute Percentages for Each Hour

# %%
# Compute percentages by hour

# final_df = pd.concat(
#     [compute_state_percentages(make_dataframe(file)) for file in all_prediction_filez]
# )

# %%
#final_df.to_csv('./data/hourly_measurements.csv')
final_df = pd.read_csv('./data/hourly_measurements.csv')

# %%
# Add genotypes

genotypes = final_df.reset_index().Animal.apply(sw.get_genotype)
genotypes[genotypes=='e4'] = 'wt'
final_df['Genotype'] = genotypes.values

# %%
fig, axs = plt.subplots(1,2,figsize=(15,10))

sns.boxplot(
    data = final_df[(final_df.Genotype == 'wt') & (final_df.State == 1)].reset_index(),
    x = 'isLight',
    y = 'Time',
    ax = axs[0]
)
axs[0].set_title('WT')

sns.boxplot(
    data = final_df[(final_df.Genotype == 'te4') & (final_df.State == 1)].reset_index(),
    x = 'isLight',
    y = 'Time',
    ax = axs[1]
)
axs[1].set_title('TE4')
# Out:
# Text(0.5, 1.0, 'TE4')

# %%
#final_df['CTime'] = final_df.reset_index().Date.dt.time.apply(lambda x: timedelta(hours=x.hour, minutes=x.minute, seconds=x.second).total_seconds()).values
final_df['CTime'] = pd.to_datetime(final_df.reset_index().Date).dt.hour.values

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,10))

sns.boxplot(
    data = final_df[(final_df.State == 1) & (final_df.Genotype == 'wt')],
    x = 'CTime',
    y = 'Time',
    ax = axs[0]
)
axs[0].set_title('wt')


sns.boxplot(
    data = final_df[(final_df.State == 1) & (final_df.Genotype == 'te4')],
    x = 'CTime',
    y = 'Time',
    ax = axs[1]
)
axs[1].set_title('te4')
# Out:
# Text(0.5, 1.0, 'te4')

# %% [markdown]
# ## Measurements in 24hr bins

# %%
data = data.reset_index()

# %%
# Find consecutive 24-hour blocks

res_index = (data.groupby('Animal').Date.diff() != timedelta(hours=1)).cumsum()
data['res_index'] = res_index
index_24 = (data.groupby('res_index')['Date'].apply(lambda df: (df - df.min()) / pd.Timedelta('1 hour') % 24 == 0) ).cumsum()
data['index_24'] = index_24

# %%
# Functions to compute percentages 24-hour version

def make_dataframe_24(filez: pd.Series) -> pd.DataFrame:
    return pd.concat([make_dataframe(file) for file in filez])

def compute_state_percentages_24(pred_df: pd.DataFrame) -> pd.DataFrame:
    pred_df['isLight'] = get_isLight(pred_df)
    stats = (pred_df.groupby(['isLight', 'State']).count()[['Time']]).reset_index()
    delta_mean = pred_df.groupby(['isLight', 'State'])['Delta'].mean()
    theta_mean = pred_df.groupby(['isLight', 'State'])['Theta'].mean()
    stats['Animal'] = pred_df.Animal.mode()[0]
    stats['Date'] = pred_df.Time.min()
    stats['Delta_mean'] = delta_mean.values
    stats['Theta_mean'] = theta_mean.values
    return stats.set_index(['Animal', 'Date'])

# %%
# Compute times (secs) per state per day

# import tqdm

# data_24 = pd.concat([compute_state_percentages_24(make_dataframe_24(data[data['index_24'] == ind].file)) for ind in tqdm.tqdm(data.index_24.unique())])
# data_24

# %%
#data_24.to_csv('./data/Daily_Measurements/d24.csv')
data_24 = pd.read_csv('./data/Daily_Measurements/d24.csv')

# %%
# Compute percentage

data_24 = data_24.reset_index()
per = pd.DataFrame(data_24.set_index(['Animal', 'Date','isLight']).groupby(level=[0,1,2])['Time'].apply(lambda x:100 * x / float(x.sum())))
state = pd.DataFrame(data_24.set_index(['Animal', 'Date','isLight']).groupby(level=[0,1,2])['State'].apply(lambda x:x))
is12 = pd.DataFrame(data_24.set_index(['Animal', 'Date','isLight']).groupby(level=[0,1,2])['Time'].apply(lambda x: float(x.sum()) >= 900*11).rename('is12'))
d24 = per.join(is12, on=['Animal', 'Date', 'isLight'])
d24['State'] = state.values
d24
# Out:
#                                            Time  is12  State
# Animal   Date                isLight
# CAF00022 2020-04-20 12:07:45 False    68.046296  True      1
#                              False    28.416667  True      2
#                              False     3.537037  True      3
#                              True     43.712963  True      1
#                              True     49.231481  True      2
# ...                                         ...   ...    ...
# KDR00036 2022-04-03 11:37:39 False    76.018519  True      2
#                              False     2.305556  True      3
#                              True      6.919192  True      1
#                              True     88.525253  True      2
#                              True      4.555556  True      3
#
# [5859 rows x 3 columns]

# %%
# Add genotypes

genotypes = d24.reset_index().Animal.apply(sw.get_genotype)
genotypes[genotypes=='e4'] = 'wt'
d24['Genotype'] = genotypes.values

# %%
fig, axs = plt.subplots(1,2,figsize=(15,10))

sns.boxplot(
    data = d24[(d24.Genotype == 'wt') & (d24.State == 1)].reset_index(),
    x = 'isLight',
    y = 'Time',
    ax = axs[0]
)
axs[0].set_title('WT')

sns.boxplot(
    data = d24[(d24.Genotype == 'te4') & (d24.State == 1)].reset_index(),
    x = 'isLight',
    y = 'Time',
    ax = axs[1]
)
axs[1].set_title('TE4')
# Out:
# Text(0.5, 1.0, 'TE4')

# %%
birthdays = data_24.Animal.apply(sw.get_birthday).values
data_24['Birthday'] = birthdays
age = (pd.to_datetime(data_24.reset_index().Date) - birthdays).dt.days
data_24['Age'] = age.values

genos = data_24.Animal.apply(sw.get_genotype).values
genos[genos == 'e4'] = 'wt'
data_24['Genotype'] = genos

temp = data_24.groupby(['Animal', 'Age', 'State']).agg({'Time': 'sum', 'Genotype': 'min'})
d = temp.groupby(level=[0,1], as_index=False)[['Time']].apply(lambda x: x / x.sum())
d['Genotype'] = temp.Genotype.values
d.reset_index(inplace=True)
d
# Out:
#         Animal  Age  State      Time Genotype
# 0     CAF00022   63      1  0.558796      te4
# 1     CAF00022   63      2  0.388241      te4
# 2     CAF00022   63      3  0.052963      te4
# 3     CAF00022   64      1  0.636806      te4
# 4     CAF00022   64      2  0.309444      te4
# ...        ...  ...    ...       ...      ...
# 2534  KDR00036  151      2  0.711481       wt
# 2535  KDR00036  151      3  0.052857       wt
# 2536  KDR00036  153      1  0.146184       wt
# 2537  KDR00036  153      2  0.820000       wt
# 2538  KDR00036  153      3  0.033816       wt
#
# [2539 rows x 5 columns]

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = (10, 7)

sns.regplot(
    data = d[(d.State==1) & (d.Genotype=='wt')],
    x = 'Age',
    y = 'Time',
);

sns.regplot(
    data = d[(d.State==1) & (d.Genotype=='te4')],
    x = 'Age',
    y = 'Time',
);

plt.legend(['WT', 'WT_CI', 'TE4', 'TE4_CI'])
plt.ylabel('Percent')
plt.title('Percentage Time Awake in 24hr vs. Age: No Filter')
# Out:
# Text(0.5, 1.0, 'Percentage Time Awake in 24hr vs. Age: No Filter')

# %%
# Implement 24 hour filter

temp = data_24.set_index(['Animal', 'Date', 'isLight']).join(is12).reset_index()
d_complete = temp[temp.is12]
d_complete = d_complete.groupby(['Animal', 'Date', 'State']).sum()
d_complete = d_complete.groupby(level=[0,1])[['Time']].transform(lambda x: x/x.sum()).reset_index()

# %%
def get_info(df, func): 
    return df.Animal.apply(func)

Geno = get_info(d_complete.reset_index(), sw.get_genotype)
Birth = get_info(d_complete.reset_index(), sw.get_birthday)
d_complete['Age'] = (pd.to_datetime(d_complete.reset_index().Date) - Birth).dt.days.values
d_complete['Genotype'] = Geno.values

sns.regplot(
    data = d_complete[(d_complete.Genotype == 'wt') & (d_complete.State==1)],
    x = 'Age',
    y = 'Time'
)

sns.regplot(
    data = d_complete[(d_complete.Genotype == 'te4') & (d_complete.State==1)],
    x = 'Age',
    y = 'Time'
)

plt.legend(['WT', 'WT_CI', 'TE4', 'TE4_CI'])
plt.ylabel('Percent')
plt.title('Percentage Time Awake in 24hr vs. Age: 24HR Filter')

plt.text(400, 0.1, f"Data Usage %.2f percent" % (len(d_complete) / len(d)))
# Out:
# Text(400, 0.1, 'Data Usage 0.71 percent')

# %%
# Implement light/dark filter

percent = data_24.groupby(['Animal', 'Date', 'isLight'])['Time'].transform(lambda x: x / x.sum())
data_24['Percent'] = percent
temp = data_24.drop(columns='index')[data_24.State == 1]
temp = pd.pivot(temp, index=['Animal', 'Date'], columns='isLight', values=['Percent'])
temp2 = temp[temp['Percent'][False] > temp['Percent'][True]]

# %%
temp3 = data_24.set_index(['Animal', 'Date']).loc[temp2.index]
temp3.loc[:, 'Percent'] = temp3.groupby(level=[0,1]).Time.transform(lambda x: x / x.sum()).values
temp4 = temp3[temp3.State==1].groupby(level=[0,1]).agg({'Percent':'sum', 'Genotype':'first', 'Age':'first'})

# %%
sns.regplot(
    data = temp4[(temp4.Genotype == 'wt') ],
    x = 'Age',
    y = 'Percent'
)

sns.regplot(
    data = temp4[(temp4.Genotype == 'te4')],
    x = 'Age',
    y = 'Percent'
)

plt.legend(['WT', 'WT_CI', 'TE4', 'TE4_CI'])
plt.ylabel('Percent')
plt.title('Percentage Time Awake in 24hr vs. Age: Light Dark Filter')

plt.text(350, 0.1, f"Data Usage %.2f percent" % (len(temp4) / len(d[d.State==1])))
# Out:
# Text(350, 0.1, 'Data Usage 0.87 percent')

# %%
# Implement both filters

li = []
for index in temp2.index:
    try:
        li.append(d_complete.set_index(['Animal', 'Date']).loc[index])
    except:
        pass
df_final = pd.concat(li)

# %%
sns.regplot(
    data = df_final[(df_final.Genotype == 'wt') & (df_final.State==1)],
    x = 'Age',
    y = 'Time'
)

sns.regplot(
    data = df_final[(df_final.Genotype == 'te4') & (df_final.State==1)],
    x = 'Age',
    y = 'Time'
)

plt.legend(['WT', 'WT_CI', 'TE4', 'TE4_CI'])
plt.ylabel('Percent')
plt.title('Percentage Time Awake in 24hr vs. Age: Both Filters')

plt.text(350, 0.1, f"Data Usage %.2f percent" % (len(df_final) / len(d)))
# Out:
# Text(350, 0.1, 'Data Usage 0.65 percent')

# %% [markdown]
# ## Check outlier animals

# %%
abnormal_df = data_24.set_index(['Animal', 'Date']).loc[temp4[temp4.Percent < 0.2].index]
abnormal_df
# Out:
#                               index  isLight  State  Time  Delta_mean  \
# Animal   Date
# CAF00026 2020-09-19 11:25:01    606    False      1  1985   -0.277973
#          2020-09-19 11:25:01    607    False      2  7705    0.202852
#          2020-09-19 11:25:01    608    False      3  1110   -0.866081
#          2020-09-19 11:25:01    609     True      1  1202   -0.503773
#          2020-09-19 11:25:01    610     True      2  8177    0.228070
# ...                             ...      ...    ...   ...         ...
# KDR00036 2022-04-03 11:37:39   5854    False      2  8210   -0.074320
#          2022-04-03 11:37:39   5855    False      3   249   -0.366099
#          2022-04-03 11:37:39   5856     True      1   685    0.271608
#          2022-04-03 11:37:39   5857     True      2  8764   -0.014269
#          2022-04-03 11:37:39   5858     True      3   451   -0.347434
#
#                               Theta_mean            Birthday  Age Genotype  \
# Animal   Date
# CAF00026 2020-09-19 11:25:01    0.547141 2020-02-20 07:30:00  212       wt
#          2020-09-19 11:25:01   -0.356920 2020-02-20 07:30:00  212       wt
#          2020-09-19 11:25:01    1.465687 2020-02-20 07:30:00  212       wt
#          2020-09-19 11:25:01    0.648168 2020-02-20 07:30:00  212       wt
#          2020-09-19 11:25:01   -0.342763 2020-02-20 07:30:00  212       wt
# ...                                  ...                 ...  ...      ...
# KDR00036 2022-04-03 11:37:39   -0.099690 2021-11-01 07:30:00  153       wt
#          2022-04-03 11:37:39    1.999486 2021-11-01 07:30:00  153       wt
#          2022-04-03 11:37:39    0.417844 2021-11-01 07:30:00  153       wt
#          2022-04-03 11:37:39   -0.139301 2021-11-01 07:30:00  153       wt
#          2022-04-03 11:37:39    1.967796 2021-11-01 07:30:00  153       wt
#
#                                Percent
# Animal   Date
# CAF00026 2020-09-19 11:25:01  0.183796
#          2020-09-19 11:25:01  0.713426
#          2020-09-19 11:25:01  0.102778
#          2020-09-19 11:25:01  0.111296
#          2020-09-19 11:25:01  0.757130
# ...                                ...
# KDR00036 2022-04-03 11:37:39  0.760185
#          2022-04-03 11:37:39  0.023056
#          2022-04-03 11:37:39  0.069192
#          2022-04-03 11:37:39  0.885253
#          2022-04-03 11:37:39  0.045556
#
# [84 rows x 10 columns]

# %%
sns.scatterplot(
    data = abnormal_df[abnormal_df.State == 1],
    x = 'Age',
    y = 'Time',
    hue = 'Animal'
)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Time'>

# %%
data.set_index(['Animal', 'Date']).loc[abnormal_df.index].loc['CAF00092']
# Out:
#                                                                   file  \
# Date
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-04 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-05 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-09 06:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
# 2021-04-10 18:43:26  /media/HlabShare/Sleep_Scoring_ckbn_noscoring_...
#
#                      res_index  index_24
# Date
# 2021-04-04 18:43:26        507       813
# 2021-04-04 18:43:26        507       813
# 2021-04-04 18:43:26        507       813
# 2021-04-04 18:43:26        507       813
# 2021-04-04 18:43:26        507       813
# 2021-04-04 18:43:26        507       813
# 2021-04-05 18:43:26        513       819
# 2021-04-05 18:43:26        513       819
# 2021-04-05 18:43:26        513       819
# 2021-04-05 18:43:26        513       819
# 2021-04-05 18:43:26        513       819
# 2021-04-05 18:43:26        513       819
# 2021-04-09 06:43:26        528       834
# 2021-04-09 06:43:26        528       834
# 2021-04-09 06:43:26        528       834
# 2021-04-09 06:43:26        528       834
# 2021-04-09 06:43:26        528       834
# 2021-04-09 06:43:26        528       834
# 2021-04-10 18:43:26        537       843
# 2021-04-10 18:43:26        537       843
# 2021-04-10 18:43:26        537       843
# 2021-04-10 18:43:26        537       843
# 2021-04-10 18:43:26        537       843
# 2021-04-10 18:43:26        537       843

# %%
rcParams['figure.figsize'] = (15,7)
plt.subplot(1,2,1)
sns.histplot(
    data = data_24.reset_index(),
    x = 'Delta_mean',
    hue = 'State',
    bins=50,
    palette=colors
)
plt.legend(['REM', 'NREM', 'Wake'])
plt.title('Distribution of Mean Delta Power Over 24hrs Block by States')
plt.xlabel('Delta Power')

plt.subplot(1,2,2)
sns.histplot(
    data = data_24.reset_index(),
    x = 'Theta_mean',
    hue = 'State',
    bins=50,
    palette=colors
)

plt.legend(['REM', 'NREM', 'Wake'])
plt.title('Distribution of Mean Theta Power Over 24hrs Block by States')
plt.xlabel('Theta Power')

sns.despine()
plt.savefig('./figures_new/Power_Distribution.pdf', format='pdf')
